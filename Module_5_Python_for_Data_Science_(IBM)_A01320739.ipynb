# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-emm-gl/blob/main/Module_5_Python_for_Data_Science_(IBM)_A01320739.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Student: Emmanuel González Calitl
#
# ID: A01320739
#
# #Module 5: Working with Numpy Arrays and simple APIs

# %% [markdown]
# #Numpy 1D Arrays:

# %%
import numpy as np
#A numpy is similar a list, each element must be of the same type

a = np.array([0,1,2,3,4])
print(a. size)
print(a.ndim)     #number of dimensions
print(a.shape)    #size of the array in each dimension
# Out:
# 5
# 1
# (5,)

# %% [markdown]
# **Basic Operations:**

# %%
#Index and slicing:
c = np.array([100, 1,2,3,0])
print(c[2])
c[3:5]
# Out:
# 2
# array([3, 0])

# %%
#Vector sums:
u = np.array([1,0])
v = np.array([0,1])

z = u + v
z
# Out:
# array([1, 1])

# %%
#Vector sums:
u = np.array([1,0])
v = np.array([0,1])

z = u - v
z
# Out:
# array([ 1, -1])

# %%
#Array multiplication with a scalar:
y = np.array([1,2])
z = 2*y
z
# Out:
# array([2, 4])

# %%
#Product of two mupy arrays:
u = np.array([1,2])
v = np.array([3,2])
z = u * v
z
# Out:
# array([3, 4])

# %%
#Dot Product:
u = np.array([1,2])
v = np.array([3,1])
z = np.dot(u, v)
z
# Out:
# 5

# %% [markdown]
# Broadcasting:
# Adding a constant to an numpy array:
#
# ![image.png](data:image/png;base64,...)

# %%
u = np.array([1,2,3,-1])
z = u + 1
z
# Out:
# array([2, 3, 4, 0])

# %%
#Universal functions:

a = np.array([1, -1, 1, -1])
a.mean()
a.max()
# Out:
# array([-2.        , -1.55555556, -1.11111111, -0.66666667, -0.22222222,
#         0.22222222,  0.66666667,  1.11111111,  1.55555556,  2.        ])

# %%
#linspace
np.linspace(-2,2, num = 10)
# Out:
# array([-2.        , -1.55555556, -1.11111111, -0.66666667, -0.22222222,
#         0.22222222,  0.66666667,  1.11111111,  1.55555556,  2.        ])

# %%
from io import IncrementalNewlineDecoder
x = np.linspace(0, 4*np.pi,100)
y = np.sin(x)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x,y)

# %%
#Test:
u = np.array([1,-1])
v = np.array([1,1])

u * v
np.dot(u,v)
# Out:
# 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Numpy 2D Arrays:

# %%
#List a
a=[[11,12,13],[21,22,23],[31,32,33]]

A = np.array(a)


A.ndim
A.shape  #First element: number of rows, second element, number of columns

A.size    #Total elements of the array
# Out:
# 9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from locale import ABDAY_1
#Slicing

print(A[0,0:2])   #First row, Columns 0 and 1


print(A[0:2,2])   #Rows 0 and 1, from Column 3
# Out:
# [11 12]
# [13 23]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The basic operations work at the same basis of the other matrix operations:
# 1. Sum
# 2. Product (Hadamard Product)

# %%
#Matrix multiplication
a=[[0,1,1],[1,0,1]]
b=[[1,1],[1,1],[-1,1]]

A = np.array(a)
B = np.array(b)

C=np.dot(A,B)
C
# Out:
# array([[0, 2],
#        [0, 2]])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Simple APIs

# %%
#API Application Program Interface

import pandas as pd
dict = {'a':[11,21,31], 'b':[12,22,32]}
df = pd.DataFrame(dict)
df.head()
df.mean()
# Out:
# a    21.0
# b    22.0
# dtype: float64

# %% [markdown]
# REST APIs
# Connecto to internet, use of AI
#
# RE Representation
#
# S State
#
# T Transform
#
# Your program is called Client

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#HTTP methods are a way of transmittin data over the internet

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Test:

# %%
a=np.array([0,1,0,1,0])

b=np.array([1,0,1,0,1])

a*b
# Out:
# array([0, 0, 0, 0, 0])

# %%
a=np.array([0,1])

b=np.array([1,0])

np.dot(a,b)
# Out:
# 0

# %%
a=np.array([1,1,1,1,1])

a+10
# Out:
# array([11, 11, 11, 11, 11])

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Certificado

# %% [markdown]
# ![image.png](data:image/png;base64,...)
