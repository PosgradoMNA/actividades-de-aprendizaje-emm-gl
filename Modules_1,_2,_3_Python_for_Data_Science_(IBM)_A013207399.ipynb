# %% [markdown]
# ### **Student: Emmanuel González Calitl**
# ### **ID: A01320739**
# **Week 1**
#
#
# 17.09.22
# -------------------------------------------------Module 1 Python Basics:

# %% [markdown]
# # Modul 1 Python Basics:

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Types:
# INT, Real (floats) Numbers with decimal point, Strings
#
# Casting:
# You can casting each number with the next methods: int(), float(), str(), bool()

# %%
float(2)
int(3.14159)
str(3.14159)
bool (126734872)
bool (0)
# Out:
# False

# %% [markdown]
# Expressions and variables:
#
# 10 + 234 - 124...
#
# Operands the numbers -> Operands
# Math symbols -> Operators
#
# We can use double slash for integer division, where the result is rounded. Be aware, in some cases, the results are not the same as regular division.

# %%
25//6
25/6
# Out:
# 4.166666666666667

# %% [markdown]
# Variables to store values:
# myVariable = 1
#
# *** Minium name of the values

# %% [markdown]
# ***** LAB *****

# %%
print ("Hello Monterrey")
print ("Hello\nMexico \\ ")  #print the traditional hello something

#Exercise Types:
#Float
6/2

#Integer (Integer division)
6//2

#Exercise Expression:
30 + 2 * 60

(30+2) * 60

x = 3 +2 *2
y = (3+2) * 2
z = x + y
print(z)
# Out:
# Hello Monterrey
# Hello
# Mexico \
# 17

# %% [markdown]
# Strings:
# It's better to think that an String is the order of letters.
#
# Escape sequences are strings that are difficult to input \n (new line), \t (tAb)
#
# Strings methods:
# Strings are methods, remember it!!!

# %% [markdown]
# ***** LAB STRINGS *****
#
# Stings are indexed, they are a sequence.
# Negative indexing are numerated from the last character to the first, i.e. inverse direction
#
# Concatenate
# Escape sequences
# Methods: upper, replace, find

# %%
a = '1'
b = '2'
c = a + b
print(c)



#Slice Method
#The first number means the index (star at 0), and the second number means the lenght from index to the last element you want start at 1

d = 'ABCDEFG'
print(d[0:2]) 

#Stride
e = 'clocrkr1e1c1t'
e[::2]

#Print out a backslash
print('\\')

#Convert the variable f to uppercase:
f = "u r wrong"
f.upper()


#Consider the variable g, and find the first index of the sub-string snow:
g = "Mary had a little lamb Little lamb, little lamb Mary had a little lamb \
Its fleece was white as snow And everywhere that Mary went Mary went, Mary went \
Everywhere that Mary went The lamb was sure to go"

g.find('snow')
g.replace("Mary", "Bob")

w = "Lizzy"
w[0:2]
# Out:
# 12
# AB
# \
# 'Li'

# %% [markdown]
# ![A1.jpg](data:image/jpeg;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# --------------------------------------------- Module 2 Python data structures

# %% [markdown]
# #Module 2 Python data structures

# %% [markdown]
# Tuples.  Immut ables
# List  Mutuables
#     difference between append and extend
#
# clone

# %%
#Tuple
A = (0,1,2,3)

#List
B = ["a", "b", "c"]
B[0] = "A"
print(B)
# Out:
# ['A', 'b', 'b']

# %%
#######################   LAB Tuples #############################
tuple1 = ('Disco',10, 1.2)
tuple1

print(tuple1[0])
print(tuple1[1])
print(tuple1[2])

#Type of each element of the tuple
print(type(tuple1[0]))
print(type(tuple1[1]))
print(type(tuple1[2]))

print(type(tuple1[-1]))
print(type(tuple1[-2]))
print(type(tuple1[-3]))

#Concatenate tuples:
tuple2 = tuple1 + ("hard rock", 10)
tuple2

#Slicing
tuple2[0:3] #Slice from index 0 to index 2
tuple2[3:5] #Slice from index 3 to index 4

#length of the tuple:
len(tuple2)

#Sorting:
Ratings = (0,9,6,5,10,8,9,6,2)
RatingsSorted = sorted(Ratings)
RatingsSorted

#Nesting
NestedT = (1, 2, ("pop","rock"), (3,4),("disco",(1,2)))
print("Element 0 of tuple ", NestedT[0])
print("Element 1 of tuple ", NestedT[1])
print("Element 2 of tuple ", NestedT[2])
print("Element 3 of tuple ", NestedT[3])
print("Element 4 of tuple ", NestedT[4])

#Print the first element in the second nested tuples:
NestedT[2][0]

#Quiz:
genres_tuple = ('pop', 'rock', 'soul', 'hard rock', 'soft rock','R&B', 'Progressive rock', 'disco')
len(genres_tuple)
genres_tuple[3]
genres_tuple[3:6]

print(genres_tuple[0:2])
genres_tuple.index('disco')

C_tuple = (-5,1,-3)
SortedC = sorted(C_tuple)
SortedC
# Out:
# Disco
# 10
# 1.2
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'int'>
# <class 'str'>
# Element 0 of tuple  1
# Element 1 of tuple  2
# Element 2 of tuple  ('pop', 'rock')
# Element 3 of tuple  (3, 4)
# Element 4 of tuple  ('disco', (1, 2))
# ('pop', 'rock')
# [-5, -3, 1]

# %%
######################### LAB Lists ##########################################

L = ["Michael Jackson", 10.1, 1982]
L

#Extend:
L.extend(['pop', 10])
L

#Append:
L.append(['pop',10])
L

#Copy and clone:
A = ["Hard rock", 10, 1.2]
B = A
print('A: ', A)
print('B: ', B)

print('B[0]: ', B[0])
A[0] = "Banana"
print('B[0]: ', B[0])    #Be aware of this change, B and A are referencing to the same list in the memory, if we can modify the lists, it should be cloned:

#Cloning
B = A[:]
B

#Quiz:
a_list = [1, 'hello',[1,2,3], True]
a_list[1]
a_list[1:4]

#Concatenate:
qw = [1,'a']
qa =[2,1,'d']

qw + qa
# Out:
# A:  ['Hard rock', 10, 1.2]
# B:  ['Hard rock', 10, 1.2]
# B[0]:  Hard rock
# B[0]:  Banana
# [1, 'a', 2, 1, 'd']

# %%
#Sets:

A = ['A', 'B', 'C','A','A','B','C']
x = set(A)
x.add('D')
print(x)

#Intersection of sets:
V = {1,2,3,4,5}
B = {1,3,9,12}

print(V & B)


###################  LAB SETs ##########################

# Verify if the element is in the set
A = {"Thriller", "Back in Black", "AC/DC"}
"AC/DC" in A

album_set1 = set(["Thriller", 'AC/DC', 'Back in Black'])
album_set2 = set([ "AC/DC", "Back in Black", "The Dark Side of the Moon"])

IntersectionSet = album_set1 & album_set2
IntersectionSet

# Find the difference in set1 but not set2

album_set1.difference(album_set2) 

# Find the union of two sets
album_set1.union(album_set2)



#Suppose that you have two sets: A and B. Set A is a superset of set B if all elements of set B are elements of set A.
#If set A is a superset of set B, then set B is a subset of set A. To check if a set is a subset of another, you use the issubset() method.
#If set A and set B are not equal, set A is a proper superset of set B.
#Logically, a set is a superset of itsel

# Check if superset
set(album_set1).issuperset(album_set2)

# Check if subset
set(album_set2).issubset(album_set1)   



A = [1, 2, 2, 1]  
B = set([1, 2, 2, 1])
print("the sum of A is:", sum(A))
print("the sum of B is:", sum(B))   #Remember Python deletes the repeated elements in a set

album_set3 = album_set1.union(album_set2)
album_set3
# Out:
# {'A', 'D', 'B', 'C'}
# {1, 3}
# the sum of A is: 6
# the sum of B is: 3
# {'AC/DC', 'Back in Black', 'The Dark Side of the Moon', 'Thriller'}

# %% [markdown]
# 18.09.22
#
# Dictionaries:

# %%
Dict = {"key1": 1, "key 2": "2", "key 3": [3,3,3], "key 4": (4,4,4)}
Dict["key 4"]

release_year_dict = {"Thriller": "1982", "Back in Black": "1980", \
                    "The Dark Side of the Moon": "1973", "The Bodyguard": "1992", \
                    "Bat Out of Hell": "1977", "Their Greatest Hits (1971-1975)": "1976", \
                    "Saturday Night Fever": "1977", "Rumours": "1977"}

release_year_dict.keys()
release_year_dict.values() 


### LAB Dictionaries ###
album_sales_dict = {"The Bodyguard":50, "Back in Black":50, "Thriller":65}
album_sales_dict["Thriller"]
# Out:
# 65

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Module 3 Python Programming Fundamentals

# %%
###### LAB #####

#Rate Back in black 8.5
rate = 8.5

if rate >= 8:
  print("This is Album is Amazing")
else:
  print("This albums isn't amazing")
# Out:
# This is Album is Amazing

# %% [markdown]
# Loops:
#
# Range: the size of a list
# A method that makes a sequence:
# range(0,5) -> 0,1,2,3,4
#
#
# for i in range(0,5)
#   (like foreach in c#)
#   i always start in 0
#   each increment is by 1
#
# while
#   run under when a condition is met

# %%
##### Quiz #####

for i in range(-4,5):
  print(i)


Genres=[ 'rock', 'R&B', 'Soundtrack', 'R&B', 'soul', 'pop']
for genre in Genres:
  print(genre)


squares=['red', 'yellow', 'green', 'purple', 'blue']
for color in squares:
  print(color)
# Out:
# -4
# -3
# -2
# -1
# 0
# 1
# 2
# 3
# 4
# rock
# R&B
# Soundtrack
# R&B
# soul
# pop
# red
# yellow
# green
# purple
# blue

# %% [markdown]
# **Functions:**
#
# Pyhton Built-in Functions
# ✈
#
# e.g.
# len: returns the lenght of a sequence
# sum: the total of the elements
# sorted: new sorted list or tuple
#
# ******* Making our functions:
# Remember the correct identation
# pass :makes nothing and satisfies the no empty value/space sentence
#
# Variadic Parameters: A variadic parameter accepts zero or more arguments of different type.
#
# A variadic paramter indicates that the block or method can be called with different number of arguments of different type else the type is specified then only instance of the type can be passed as arguments.
#
# Be aware of the accesiblity of the parameters. The inner parameters/variables of the functions can't be accesed from out. It isn't a global variable.
#
# Scope: Local variables
#
# def add1(a):
#   b = a + 1
# return b

# %%
##### Lab Loops #####

#Quiz

#1. Come up with a function that divides the first input by the second input:

def div(a,b):
  pass
  return a/b

print(div(6,2))

#2. Can the con function we defined before be used to add two integers or strings?
#Yes, the functions can sum two integers or concatenate two strings, but not mix integers with strings.

def con(a, b):
    return(a + b)
  

con(2,2)

con("Dog" ," Cat")

#con(2, "Chair")  ---------- Error

#3. Can the con function we defined before be used to concatenate lists or tuples?
#Yes!!

list1 = [789, 987, 741, 753, 951]
list2 = [123, 456, 789]

tuple1 = (789, 987, 741, 753, 951)
tuple2 = (123, 456, 789)

con(list1, list2)
con(tuple1, tuple2)

#con(list1, tuple1) Error!!! can't mix different types of sequences
# Out:
# 3.0
# (789, 987, 741, 753, 951, 123, 456, 789)

# %% [markdown]
# **Objects & classes**
#
# Every object has:
#
#
# 1. A type
# 2. An internal data presentation
# 3. A set of procedures for interacting with the object (methods)
#
# ***An object is an instance of a particular type***
#
# Class:
# ![image.png](data:image/png;base64,...)
#
# Class: Circle
#
# Attributes:
# Color, Radius
#
# ***Defining***
# class Circle(object):
#
# *** Constructor, initialize attributes ***
#   def _ _init_ _(self, raidus, color):
#     self.radius = radius;
#     self.color = color;
#
# *** Methods: ***
# def add_radius(self, r):
#   self.radius = self.radius + r
#   return(self.radius)
#
# ![image.png](data:image/png;base64,...)
#
#
# ***dir***
# The “D I R” function is useful for obtaining the list of data attributes and methods associated

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#### Lab #####

class Car(object):
    def __init__(self,make,model,color):
        self.make=make;
        self.model=model;
        self.color=color;
        self.owner_number=0 
    def car_info(self):
        print("make: ",self.make)
        print("model:", self.model)
        print("color:",self.color)
        print("number of owners:",self.owner_number)
    def sell(self):
        self.owner_number=self.owner_number+1

myCar = Car("BMW", "M3", "Red")
myCar.car_info()
myCar.sell()
myCar.car_info()
# Out:
# make:  BMW
# model: M3
# color: Red
# number of owners: 0
# make:  BMW
# model: M3
# color: Red
# number of owners: 1

# %%
from typing import Text
##### Quiz #####

class analysedText(object):
    
    def __init__ (self, text):
        # TODO: Remove the punctuation from <text> and make it lower case.
        # TODO: Assign the formatted text to a new attribute called "fmtText"
        self.fmtText = str(text)
        self.fmtText.replace(".", "")
        self.fmtText.replace("!", "")
        self.fmtText.replace(",", "")
        self.fmtText.replace("?", "")
        self.fmtText.lower()
        
    def freqAll(self): 
      self.Dictionary = {} 
      self.listValues = []
      
      self.SetText = set(self.fmtText.Split())          #Get Keys
      self.listKeys = list(self.SetText)

      for word in self.SetText:                         #Get Values
        self.listValues.append(self.SetText.count(word))

      for i in self.listKeys:
        Dictionary = dict.fromkeys(self.listKeys[i], self.listValues[i])
      
      return Dictionary

    def freqOf(self, word):
      # TODO: return the number of occurrences of <word> in <fmtText>
       self.freq = self.fmtText.count(word)
       return self.freq

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
