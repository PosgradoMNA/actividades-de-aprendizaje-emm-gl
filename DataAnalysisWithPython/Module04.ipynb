# %% [markdown]
# # Data Analysis with Python (IBM) Module 4 Model Development:
#
# Materia: Ciencia y Analitica de Datos
#
# Profesor titular: Maria de la Paz Rico Fernandez
#
# Profesor tutor: Orlando Figon Cruz
#
# Fecha: 1 de Novimebre de 2022
#
# Emmanuel Gonzalez Calitl
#
# A01302739
#
# (Sin acentos añadidos)

# %% [markdown]
# #Model Development:
#
# A model or estimatot can be thought of as a mathematical equation used to predict a value given or more other values.
# * Relating one or more independent variables to dependent variables.
# * Usually the more relevent data you have the more accurate your model is:
#
#
# Why more data is better:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Linear and Multiple Linear Regression
#
# Linear regression (One independent variable to make a prediction)
#
# Multiple linear regresion (two or more independent variables to make a prediction)
#
# Keywords:
# Predictor (Indepndent variable), target (dependent variable).
#
# y = b0 + b1(x)
#
# With this relationship we assume a linear prediction.
#
# With training points we fit the model, the results of the trainned points are the parameters (b0 and b1).
#
# We have also noise, because there are other factors what affect the target.
#
# Dont forget that the model isn't always correct, only make a prediction.
#
# Steps:
#
# 1. Import linear model
# 2. Create a linear regression object
# *  Define the predictor variable and target variable.
# * Fit the model
# * We can obtain a prediction.

# %% [markdown]
# *** Multiple linear regression ***
#
# Remember multiple precitor variables:
#
#  Y = b0 + b1(x) + b2(x2) + b3(x3) + ...
#
#  Steps:
#  1. We can extract the for 4 predictor variables and store them in variable Z
# 2. Then train the model as before
# 3. We can also obtain a prediction
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Model Evaluation using Visualization
#
#  ***Regression plots:***
#  * The scatterplot: Where each point represents a different Y.
#  * The fitted linear regression line Y^
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Residual Plot***
#
# That plot shows the error between each target value vs the predicted value:
# n
#
# ![image.png](data:image/png;base64,...)
#
#
# We expecto to have a zero mean:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Distribution Plots***
#
#  Target values vs predicted values:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Polynomial Regression and Pipelines
#
# To use when a lineal reggression don't make good relationship.
#
# A special case of the linear regression, when the points have a curvilinear relationship:
#
# Quadratic: Y = b0 + b1 (x) + b2 X^2
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Measures for In-Sample Evaluation
#
# How to evaluate a model with visualization:
#
# (In Sample evaluation)
#
# * A way to numerically determine how good the model fits on dataset.
# * Two important measure to determine the fot of a model.
#   * MSR
#   * R^2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# R^2 tends to 1 is a good regression, 0 a bad regression.

# %% [markdown]
# #Prediction and Decision Making:
#
# ***How to determine that our model is correct **
#
# * First the predicteed values makes sense.
# *  Visualization
# * Numerical measures for evaluation
# * Comparting between various models

# %% [markdown]
# Do the predicted values makes sense:
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Lab:

# %%
#Importing libraries:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Get the data set:

path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'

df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# #Linear regression and multiple:

# %%
#Librarie:

from sklearn.linear_model import LinearRegression

#Create the object:
lm =LinearRegression()
lm
# Out:
# LinearRegression()

# %%
#Set the predictor variable and target:
X = df[['highway-mpg']]
Y = df['price']

lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %%
lm.intercept_
# Out:
# 38423.3058581574

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Price = 38423.31 - -821.73 (Highway=mpg)

# %% [markdown]
# ***Question #1 a):
# Create a linear regression object called "lm1".***

# %%
lm1 = LinearRegression()
lm1
# Out:
# LinearRegression()

# %% [markdown]
# ***Question #1 b):
# Train the model using "engine-size" as the independent variable and "price" as the dependent variable?***

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
#Set the predictor variable and target:
X = df[['engine-size']]
Y = df['price']

lm1.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# Question #1 c):
# Find the slope and intercept of the model.

# %%
print('intercept: ')
print(lm1.intercept_)
print('slope: ')
print(lm1.coef_)
# Out:
# intercept:
# -7963.338906281042
# slope:
# [166.86001569]

# %% [markdown]
# ***Question #1 d):
# What is the equation of the predicted line? You can use x and yhat or "engine-size" or "price".***

# %%
yhat = -7963.33 + 166.86 * X
Price = -7963.33 + 166.86 * df['engine-size']

# %% [markdown]
# #Graded Review Questions Instructions

# %% [markdown]
# ![Screen Shot 2022-11-01 at 21.38.47.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-11-01 at 21.38.58.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-11-01 at 21.39.04.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-11-01 at 21.39.09.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-11-01 at 21.39.15.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-11-01 at 22.38.46.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-11-01 at 22.38.55.png](data:image/png;base64,...)
