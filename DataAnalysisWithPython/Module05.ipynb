# %% [markdown]
# # Data Analysis with Python (IBM) Module 5 Model Evaluation and Refinement
#
# Materia: Ciencia y Analitica de Datos
#
# Profesor titular: Maria de la Paz Rico Fernandez
#
# Profesor tutor: Orlando Figon Cruz
#
# Fecha: 9 de Novimebre de 2022
#
# Emmanuel Gonzalez Calitl
#
# A01302739
#
# (Sin acentos añadidos)

# %% [markdown]
# #Model evaluation

# %% [markdown]
# *  Partionate our data, it's recommendable separate 70% to train the model and the rest to test the model.
#
# * Popular function to separate model is the function split:
#
#
# ```
# #Function train_test_split()
# x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = 0)
# ```
#
# ***Generalization error***
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Cross validation***
# * Most common out of sample evaluation metrics
# * more effective use of data:
#
# ![Screen Shot 2022-11-09 at 19.49.51.png](data:image/png;base64,...)
# ```
# # Function: cross_val_score()
# ```
# ![Screen Shot 2022-11-09 at 19.50.48.png](data:image/png;base64,...)

# %% [markdown]
# ***Overfitting, Underfitting and Model Selection***

# %% [markdown]
# * How to select the correct polinomial order of the functions.
#
# **Underfitting:**
# When the model isn''t flexible and don't match the data. Have a big test error.
#
# **Overfitting:**
# When the model is so flexible and learn the data and noise.
#
# ![Screen Shot 2022-11-09 at 19.57.37.png](data:image/png;base64,...)

# %% [markdown]
# Always will be errors or noise.
#
#
# It's a good idea to check always the errors in this case Rˆ2:
#
# ![Screen Shot 2022-11-09 at 20.01.03.png](data:image/png;base64,...)

# %% [markdown]
# **Ridge Regression**

# %% [markdown]
# Ridge Regression Prevents overfitting:
#
# In many case the data have outliers.
#
# Ridge regression controls the magnitude of these polynominial coefficients by alpha.
#
# In order to select alpha we use cross validation:
#
# ![Screen Shot 2022-11-09 at 20.06.16.png](data:image/png;base64,...)

# %% [markdown]
# #Graded Review Questions Instructions

# %% [markdown]
# ---
#
#
#
# ---
#
#
# ![Screen Shot 2022-11-09 at 20.22.21.png](data:image/png;base64,...)![Screen Shot 2022-11-09 at 20.22.29.png](data:image/png;base64,...)![Screen Shot 2022-11-09 at 20.22.35.png](data:image/png;base64,...)

# %% [markdown]
# # Exam:
#
# ![Screen Shot 2022-11-09 at 20.32.01.png](data:image/png;base64,...)![Screen Shot 2022-11-09 at 20.32.09.png](data:image/png;base64,...)![Screen Shot 2022-11-09 at 20.32.25.png](data:image/png;base64,...)![Screen Shot 2022-11-09 at 20.32.32.png](data:image/png;base64,...)![Screen Shot 2022-11-09 at 20.32.39.png](data:image/png;base64,...)![Screen Shot 2022-11-09 at 20.32.55.png](data:image/png;base64,...)![Screen Shot 2022-11-09 at 20.33.11.png](data:image/png;base64,...)![Screen Shot 2022-11-09 at 20.33.16.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-11-09 at 20.34.16.png](data:image/png;base64,...)![Screen Shot 2022-11-09 at 20.34.41.png](data:image/png;base64,...)
